# %% [markdown]
# # **StatQuest**.. Long Short-Term Memory (LSTM)

# %% [markdown]
# # Activation Functions
#
#   * Sigmoid:
#     + **Returns the output** Between **0 and 1**
#
#   * Tanh:
#     + **Returns the output** Between **-1 and 1**

# %% [markdown]
# ## Cell State:
#   + Aka calles Long Term Memory, althoug LTM can be modified by X[mul] and +[sum], thers no W, B to modify it directly
#
#   + This lack of W allows the LTM to flow trough the series of unrolled units without causing the grad to **Vanish** or **Explode**
#
# ## Hidden State:
#   + This repr the Short Term Memory, and we can directly modifiy it with W

# %% [markdown]
# ![The-structure-of-the-Long-Short-Term-Memory-LSTM-neural-network-Reproduced-from-Yan.png](data:image/png;base64,...)

# %% [markdown]
# # ------------------------------------------------------------

# %% [markdown]
# ## First Sigmoid Unit:
#    + The output/the first unit of LSTM determines **what Precentage of LTM will be remember**
#    + this usualy called the forget gate

# %% [markdown]
#
#
#
#  ![Screenshot from 2024-10-25 10-54-02.png](data:image/png;base64,...)

# %% [markdown]
# # ------------------------------------------------------------

# %% [markdown]
# ## Second and Third Unit
#   + This part of the LSTM unit **Determines how we should Update the LTM,**
#   + and Its usualy **calles The Input Gate**

# %% [markdown]
# ![Screenshot from 2024-10-25 11-02-33.png](data:image/png;base64,...)

# %% [markdown]
# # ------------------------------------------------------------

# %% [markdown]
# ## The Final Stage of the LSTM
#   + This final Stage u**pdate the Short Term Memory**
#
#   + we **start with** the ** New Long Term Memory** above and use it **input to the Tanh Func**
#
#   + And the output or This **New Short Term Memory**[0.98] is also the** Output From This Entire LSTM** Unit
#
#   + Also this stage is called the **Output Gate**

# %% [markdown]
# ![Screenshot from 2024-10-25 11-08-06.png](data:image/png;base64,...)

# %% [markdown]
#  # ------------------------------------------------------------

# %% [markdown]
# # All 3 Stages in a Single LSTM unit

# %% [markdown]
# ![Screenshot from 2024-10-25 11-16-55.png](data:image/png;base64,...)

# %% [markdown]
#  ------------------------------------------------------------

# %% [markdown]
# # The Unrolled Model of LSTM
#
#   + So this Abstract Diagram show how unrolled L**STM get Seqential data and give output**
#
#   + First get the New LTM and New STM,, and then Update or plug those value to The LTM and STM,
#
#   + And Unroll the LSTM and do that math with ramaining input values,,
#
#   + so The units get data from day 1 to day 4 , and calculate the LTM, STM and unrolled the model
#
#   + And the Final STM is the output from the Unrolled LSTM
#
#   + In Summary **using Separate Path for LTM  And STM**, LSTM Network **Avoid the Exploding / Vanishing Gradient Problem**

# %% [markdown]
# ![Screenshot from 2024-10-25 11-28-09.png](data:image/png;base64,...)
